# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('Statistics Project (Responses).xlsx')

# %%
df
# Out:
#                   Timestamp                     Name Gender:-      Age:-  \
# 0   2021-10-25 22:36:16.488                    Sompa   Female  18-25 yrs
# 1   2021-10-25 23:02:37.406  Soumya Ranjan Pattnaik      Male  26-35 yrs
# 2   2021-10-25 23:03:13.361                Tathastu’     Male  18-25 yrs
# 3   2021-10-25 23:04:43.294       Rahul Kumar Keshri     Male  18-25 yrs
# 4   2021-10-25 23:10:18.149            Nirman Bisoyi     Male  26-35 yrs
# ..                      ...                      ...      ...        ...
# 140 2021-11-13 12:56:56.579            Diksha kumari     Male    60+ yrs
# 141 2021-11-13 13:01:18.508          Debabrata panda     Male    60+ yrs
# 142 2021-11-13 13:03:44.020                    sweta   Female  46-59 yrs
# 143 2021-11-13 13:11:06.687            Ranjita samal   Female    60+ yrs
# 144 2021-11-13 13:17:52.780            Niharika ojha   Female  36-45 yrs
#
#     What is your Monthly Income (INR):-  \
# 0                         20,001-50,000
# ...

# %%
df.dtypes
# Out:
# Timestamp                                                                datetime64[ns]
# Name                                                                             object
# Gender:-                                                                         object
# Age:-                                                                            object
# What is your Monthly Income (INR):-                                              object
# Please choose your educational qualification                                     object
# Are you aware of Electric Vehicles(EV)                                           object
# Do you think Electric Vehicles (EV) are beneficial to the environment            object
# Are you willing to purchase any Electric Vehicle(EV)                             object
# Where would you like the most to charge the Electric Vehicle(EV)                 object
# Please share your views on cost [High Cost of EV’s]                              object
# ...

# %%
df.shape
# Out:
# (145, 22)

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                0
# Name                                                                     0
# Gender:-                                                                 0
# Age:-                                                                    0
# What is your Monthly Income (INR):-                                      0
# Please choose your educational qualification                             0
# Are you aware of Electric Vehicles(EV)                                   1
# Do you think Electric Vehicles (EV) are beneficial to the environment    0
# Are you willing to purchase any Electric Vehicle(EV)                     0
# Where would you like the most to charge the Electric Vehicle(EV)         0
# Please share your views on cost [High Cost of EV’s]                      0
# Please share your views on cost [High Part Replacement Cost]             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 22 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Timestamp                                                              145 non-null    datetime64[ns]
#  1   Name                                                                   145 non-null    object
#  2   Gender:-                                                               145 non-null    object
#  3   Age:-                                                                  145 non-null    object
#  4   What is your Monthly Income (INR):-                                    145 non-null    object
#  5   Please choose your educational qualification                           145 non-null    object
# ...

# %%
df=df.drop(['Timestamp','Name'],axis=1)

# %%
df
# Out:
#     Gender:-      Age:- What is your Monthly Income (INR):-  \
# 0     Female  18-25 yrs                       20,001-50,000
# 1       Male  26-35 yrs                     50,001-1,00,000
# 2       Male  18-25 yrs                     50,001-1,00,000
# 3       Male  18-25 yrs                       20,001-50,000
# 4       Male  26-35 yrs                     50,001-1,00,000
# ..       ...        ...                                 ...
# 140     Male    60+ yrs                  More Than 1,00,000
# 141     Male    60+ yrs                  More Than 1,00,000
# 142   Female  46-59 yrs                       20,001-50,000
# 143   Female    60+ yrs                  More Than 1,00,000
# 144   Female  36-45 yrs                     50,001-1,00,000
#
#     Please choose your educational qualification  \
# 0                                  Post Graduate
# 1                                  Post Graduate
# 2                                       Graduate
# ...

# %% [markdown]
# Demographics

# %%
df['Gender:-'].value_counts()
# Out:
# Male      112
# Female     31
# Others      2
# Name: Gender:-, dtype: int64

# %%
df['Gender:-'].value_counts(normalize=True)
# Out:
# Male      0.772414
# Female    0.213793
# Others    0.013793
# Name: Gender:-, dtype: float64

# %%
df['Gender:-'].value_counts().plot(kind="pie",labels=['Male','Female','Others'],autopct='%.2f',shadow=True)
# Out:
# <AxesSubplot:ylabel='Gender:-'>

# %%
df['Age:-'].value_counts()
# Out:
# 26-35 yrs    80
# 18-25 yrs    28
# 60+ yrs      25
# 36-45 yrs     8
# 46-59 yrs     4
# Name: Age:-, dtype: int64

# %%
df['Age:-'].value_counts(normalize=True)
# Out:
# 26-35 yrs    0.551724
# 18-25 yrs    0.193103
# 60+ yrs      0.172414
# 36-45 yrs    0.055172
# 46-59 yrs    0.027586
# Name: Age:-, dtype: float64

# %%
df['Age:-'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df['Please share your views on cost [High Cost of EV’s]'].value_counts()
# Out:
# Agree                55
# Neutral              42
# Disagee              22
# Strongly Agree       21
# Strongly Disagree     5
# Name: Please share your views on cost [High Cost of EV’s], dtype: int64

# %%
df['Please share your views on cost [High Cost of EV’s]'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df['Please share your views on cost [High Part Replacement Cost]'].value_counts()
df['Please share your views on cost [High Part Replacement Cost]'].value_counts().plot(kind="bar",color='Green')
# Out:
# <AxesSubplot:>

# %%
df['Please share your views on cost [High Operating Cost]'].value_counts()
df['Please share your views on cost [High Operating Cost]'].value_counts().plot(kind="bar",color='Orange')
# Out:
# <AxesSubplot:>

# %%
df['Please share your views on cost [High Cost of Insurance Availability]'].value_counts()
df['Please share your views on cost [High Cost of Insurance Availability]'].value_counts().plot(kind="bar",color='Yellow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Count plot on Cost factor of Electric vehicles, we see most people agree to the fact that the overall cost and part replacement costs are high while they disagree that the operating costs are also high. This can also be considered as one of the factors affecting the adoption on Evs.
#
# As we saw in the awareness plot the age group of 26-35 is most aware we see the willingness to buy electric vehicle for the same age group is maximum while 46-59 age group has least.
#
# From the plot shown below for understanding the respondents on the cost of Electric vehicles, we can conclude that:
#
# Though maximum number of people agree that the overall cost and the part replacement cost of Electric vehicle are quite high, respondents disagree that the operating cost is high.

# %%
plt.figure(figsize=(25, 6))

plt.subplot(1,4,1)
plt.title('Unavailability of Technicians')
df['Please share your views on services [Unavailability of Technicians]'].value_counts().plot(kind="bar",color='Blue')

plt.subplot(1,4,2)
plt.title('Lack of Charging Infrastructure')
df['Please share your views on services [Lack of Charging Infrastructure]'].value_counts().plot(kind="bar",color='Yellow')


plt.subplot(1,4,3)
plt.title('Lack of Refuel Location')
df['Please share your views on services [Lack of Refuel Location]'].value_counts().plot(kind="bar",color='Green')


plt.subplot(1,4,4)
plt.title('Long Charging Duration')
df['Please share your views on services [Long Charging Duration]'].value_counts().plot(kind="bar",color='Orange')
# Out:
# <AxesSubplot:title={'center':'Long Charging Duration'}>

# %%
plt.figure(figsize=(25, 6))

plt.subplot(1,4,1)
plt.title('High Safety')
df['Please share your views on services [High Safety]'].value_counts().plot(kind="bar",color='Red')


plt.subplot(1,4,2)
plt.title('High Mileage')
df['Please share your views on services [High Mileage]'].value_counts().plot(kind="bar",color='Olive')


plt.subplot(1,4,3)
plt.title('Lack of Parts Availability')
df['Please share your views on services [Lack of Parts Availability]'].value_counts().plot(kind="bar",color='Orange')


plt.subplot(1,4,4)
plt.title('Lack Of Government Support')
df['Please share your views on services [Lack Of Government Support]'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:title={'center':'Lack Of Government Support'}>

# %% [markdown]
# **Observations From the plots:
# 1. The aim of this study was to determine the main factors affecting electric vehicle adoption. This was done by utilizing the SPSS software for statistical analysis where Cross-tabulations were executed to determine traits affecting electric vehicle adoption. The analysis conducted displayed that no human factors such as age and gender influence the purchase decisions of an electric vehicle.
#
# 2. Currently there exists no charging infrastructure for the EV which is one of the major reasons of little adoption of the EV today. The government can provide incentives to put up new charging stations to attract people to use electric vehicles. The incentives offered by the government can include the removal of taxes on the vehicles which significantly reduces the total cost of the vehicle.
#
# 3. There is currently a lack of technicians available to service and maintain the EVs. Programs must be developed to educate technicians on the proper procedures and equipment to use when conducting service and repairs on these vehicles.
#
# 4. The main problem is not associated with the cost of the vehicle but rather the availability of proper infrastructure for charging, lack of availability of parts. While respondents do will to but electric vehicles, but various factors mentioned are affecting the adoption of the vehicles.
